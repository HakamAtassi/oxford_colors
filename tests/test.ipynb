# %%
import matplotlib.pyplot as plt
import numpy as np
from oxford_colors import oxford_style, mpl_palette, OXFORD_COLORS, DEFAULT_PALETTE
from oxford_colors.graph_container import containerize

# Sample data for testing
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
data = np.random.normal(0, 1, 1000)

with oxford_style(), containerize("test.zip", files=["test_oxford_colors.py"], variables=[x, y1, y2]):
    plt.plot(x, y1)
    plt.plot(x, y2)
    plt.title("test")
    plt.savefig("testid.png", dpi=1200)
    plt.show()
# Out:
#   + test.ipynb
#   + test_vars.pkl  (pickle)
#   + testid.png
#   + test_oxford_colors.py
# Container: test.zip
